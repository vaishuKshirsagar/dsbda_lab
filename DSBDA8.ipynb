# %% [markdown]
# # Name: Vaishnavi Kshirsagar
# # Roll No.: TCOD73
# # Batch: T12

# %%
import seaborn as sb

# %%
sb.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
ds = sb.load_dataset("titanic")

# %%
ds
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
sb.scatterplot(data = ds, x = "age", y = "fare")
# Out:
# <Axes: xlabel='age', ylabel='fare'>

# %%
sb.scatterplot(data = ds, x = "age", y = "fare", hue = "class")
# Out:
# <Axes: xlabel='age', ylabel='fare'>

# %%
sb.scatterplot(data = ds, x = "age", y = "fare", hue = "embark_town")
# Out:
# <Axes: xlabel='age', ylabel='fare'>

# %%
sb.scatterplot(data = ds, x = "age", y = "fare", hue = "sex", size = 100)
# Out:
# <Axes: xlabel='age', ylabel='fare'>

# %%
sb.scatterplot(data = ds, x = "age", y = "fare", hue = "sex", size = 20, style = "alive")
# Out:
# <Axes: xlabel='age', ylabel='fare'>

# %%
sb.scatterplot(data = ds, x = "age", y = "fare", hue = "sex", size = 20, style = "alive", palette = "YlGnBu")
# Out:
# <Axes: xlabel='age', ylabel='fare'>

# %%
sb.scatterplot(data = ds, x = "age", y = "fare", hue = "sex", size = 20, style = "alive", palette = "YlGnBu", legend = "full")
# Out:
# <Axes: xlabel='age', ylabel='fare'>

# %%
ds.dropna()
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 1           1       1  female  38.0      1      0  71.2833        C  First
# 3           1       1  female  35.0      1      0  53.1000        S  First
# 6           0       1    male  54.0      0      0  51.8625        S  First
# 10          1       3  female   4.0      1      1  16.7000        S  Third
# 11          1       1  female  58.0      0      0  26.5500        S  First
# ..        ...     ...     ...   ...    ...    ...      ...      ...    ...
# 871         1       1  female  47.0      1      1  52.5542        S  First
# 872         0       1    male  33.0      0      0   5.0000        S  First
# 879         1       1  female  56.0      0      1  83.1583        C  First
# 887         1       1  female  19.0      0      0  30.0000        S  First
# 889         1       1    male  26.0      0      0  30.0000        C  First
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
ds = sb.load_dataset("titanic")

# %%
sb.histplot(ds["fare"])
# Out:
# <Axes: xlabel='fare', ylabel='Count'>

# %%
sb.histplot(ds["fare"], kde = True)
# Out:
# <Axes: xlabel='fare', ylabel='Count'>

# %%
sb.histplot(ds["fare"], kde = True, bins = 30)
# Out:
# <Axes: xlabel='fare', ylabel='Count'>

# %%
sb.displot(ds["fare"])

# %%
sb.displot(ds["fare"], kde = True, bins = 20)

# %%
sb.barplot(x = "fare", y = "age", data = ds)
# Out:
# <Axes: xlabel='fare', ylabel='age'>

# %%
sb.barplot(x="sex", y="age", hue="sex", data=ds, palette="YlGnBu", legend=False)
# Out:
# <Axes: xlabel='sex', ylabel='age'>

# %%
sb.barplot(x = "fare", y = "age", data = ds, palette = "YlGnBu", hue = "class")
# Out:
# <Axes: xlabel='fare', ylabel='age'>

# %%
sb.stripplot(data = ds, x = "fare", y = "age", hue = "class", palette = "dark")
# Out:
# <Axes: xlabel='sex', ylabel='age'>

# %%
sb.stripplot(data = ds, x = "fare", y = "age", hue = "class", palette = "dark", dodge = True)
# Out:
# <Axes: xlabel='fare', ylabel='age'>

# %%
sb.jointplot(data = ds, x = "fare", y = "age")

# %%
sb.jointplot(data = ds, x = "fare", y = "age", kind = "reg")

# %%
sb.jointplot(data = ds, x = "fare", y = "age", kind = "kde")

# %%
sb.jointplot(data = ds, x = "fare", y = "age", kind = "kde", fill = True)

# %%
sb.jointplot(data = ds, x = "fare", y = "age", kind = "kde", fill = True, cmap = "YlGnBu")

# %%
sb.jointplot(data = ds, x = "fare", y = "age", kind = "hex", cmap = "YlGnBu")

# %%
sb.pairplot(ds.select_dtypes(["number"]), hue = "pclass", palette = "bright")
